# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import random

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config1 import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url ="http://api.openweathermap.org/data/2.5/weather?q=&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=city&appid=caa2224202800d84f5136034e13a12e0

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})
        

    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 5 | kapaa
# Processing Record 2 of Set 5 | asau
# Processing Record 3 of Set 5 | husavik
# Processing Record 4 of Set 5 | busselton
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | ushuaia
# Processing Record 7 of Set 5 | tessalit
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | mecca
# Processing Record 10 of Set 5 | hanmer springs
# Processing Record 11 of Set 5 | vao
# Processing Record 12 of Set 5 | saint george
# Processing Record 13 of Set 5 | souillac
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | georgetown
# Processing Record 16 of Set 5 | neryungri
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | rikitea
# Processing Record 19 of Set 5 | inuvik
# Processing Record 20 of Set 5 | cabo san lucas
# Processing Record 21 of Set 5 | aasiaat
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | punta arenas
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | albany
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | trairi
# Processing Record 29 of Set 5 | sao joao da barra
# Processing Record 30 of Set 5 | nikolskoye
# Processing Record 31 of Set 5 | nehe
# Processing Record 32 of Set 5 | torbay
# Processing Record 33 of Set 5 | butaritari
# Processing Record 34 of Set 5 | saint-francois
# Processing Record 35 of Set 5 | castro
# Processing Record 36 of Set 5 | hobart
# Processing Record 37 of Set 5 | mataura
# Processing Record 38 of Set 5 | grand river south east
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | sergeyevka
# Processing Record 42 of Set 5 | tuktoyaktuk
# Processing Record 43 of Set 5 | lata
# Processing Record 44 of Set 5 | port elizabeth
# Processing Record 45 of Set 5 | hatillo
# Processing Record 46 of Set 5 | cape town
# Processing Record 47 of Set 5 | atuona
# Processing Record 48 of Set 5 | vestmannaeyjar
# Processing Record 49 of Set 5 | pokhara
# Processing Record 50 of Set 5 | jamestown
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | clyde river
# Processing Record 4 of Set 6 | zhob
# Processing Record 5 of Set 6 | podporozhye
# Processing Record 6 of Set 6 | bluff
# Processing Record 7 of Set 6 | taolanaro
# Processing Record 8 of Set 6 | samusu
# Processing Record 9 of Set 6 | jungapeo
# Processing Record 10 of Set 6 | pontal do parana
# Processing Record 11 of Set 6 | new norfolk
# Processing Record 12 of Set 6 | hilo
# Processing Record 13 of Set 6 | leningradskiy
# Processing Record 14 of Set 6 | tumannyy
# Processing Record 15 of Set 6 | taga
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | port moresby
# Processing Record 18 of Set 6 | yellowknife
# Processing Record 19 of Set 6 | illoqqortoormiut
# Processing Record 20 of Set 6 | puerto ayora
# Processing Record 21 of Set 6 | los llanos de aridane
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | khatanga
# Processing Record 24 of Set 6 | bredasdorp
# Processing Record 25 of Set 6 | llata
# Processing Record 26 of Set 6 | coquimbo
# Processing Record 27 of Set 6 | norman wells
# Processing Record 28 of Set 6 | dikson
# Processing Record 29 of Set 6 | kismayo
# Processing Record 30 of Set 6 | kaitangata
# Processing Record 31 of Set 6 | saleaula
# Processing Record 32 of Set 6 | pemangkat
# Processing Record 33 of Set 6 | puerto el triunfo
# Processing Record 34 of Set 6 | rio gallegos
# Processing Record 35 of Set 6 | barentsburg
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | urengoy
# Processing Record 38 of Set 6 | tarkwa
# Processing Record 39 of Set 6 | vidalia
# Processing Record 40 of Set 6 | el estor
# Processing Record 41 of Set 6 | avarua
# Processing Record 42 of Set 6 | luanda
# Processing Record 43 of Set 6 | dauriya
# Processing Record 44 of Set 6 | houston
# Processing Record 45 of Set 6 | carlisle
# Processing Record 46 of Set 6 | margate
# Processing Record 47 of Set 6 | sumkino
# Processing Record 48 of Set 6 | sahrak
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | east london
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | oppdal
# Processing Record 3 of Set 7 | ribeira grande
# Processing Record 4 of Set 7 | muros
# Processing Record 5 of Set 7 | ubinskoye
# Processing Record 6 of Set 7 | martapura
# Processing Record 7 of Set 7 | touros
# Processing Record 8 of Set 7 | dukhovshchina
# Processing Record 9 of Set 7 | pangnirtung
# Processing Record 10 of Set 7 | hambantota
# Processing Record 11 of Set 7 | klaksvik
# Processing Record 12 of Set 7 | vardo
# Processing Record 13 of Set 7 | niamtougou
# Processing Record 14 of Set 7 | guaruja
# Processing Record 15 of Set 7 | attawapiskat
# Processing Record 16 of Set 7 | sarangani
# Processing Record 17 of Set 7 | manakara
# Processing Record 18 of Set 7 | orel-izumrud
# Processing Record 19 of Set 7 | sinnamary
# Processing Record 20 of Set 7 | carnarvon
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | vaini
# Processing Record 23 of Set 7 | misratah
# Processing Record 24 of Set 7 | sentyabrskiy
# Processing Record 25 of Set 7 | byron bay
# Processing Record 26 of Set 7 | male
# Processing Record 27 of Set 7 | chuy
# Processing Record 28 of Set 7 | kenai
# Processing Record 29 of Set 7 | sassandra
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | luderitz
# Processing Record 32 of Set 7 | belushya guba
# Processing Record 33 of Set 7 | puerto del rosario
# Processing Record 34 of Set 7 | kieta
# Processing Record 35 of Set 7 | vaitupu
# Processing Record 36 of Set 7 | iqaluit
# Processing Record 37 of Set 7 | kegayli
# Processing Record 38 of Set 7 | ndele
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | tsihombe
# Processing Record 41 of Set 7 | nizhneyansk
# Processing Record 42 of Set 7 | chokurdakh
# Processing Record 43 of Set 7 | bousse
# Processing Record 44 of Set 7 | hermanus
# Processing Record 45 of Set 7 | dunning
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | samarai
# Processing Record 48 of Set 7 | saurimo
# Processing Record 49 of Set 7 | pyay
# Processing Record 50 of Set 7 | axim
# Processing Record 1 of Set 8 | mys shmidta
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | malpe
# Processing Record 4 of Set 8 | lagoa
# Processing Record 5 of Set 8 | algiers
# Processing Record 6 of Set 8 | yar-sale
# Processing Record 7 of Set 8 | mergui
# Processing Record 8 of Set 8 | port hedland
# Processing Record 9 of Set 8 | faanui
# Processing Record 10 of Set 8 | rabo de peixe
# Processing Record 11 of Set 8 | hithadhoo
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | korla
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | dubbo
# Processing Record 16 of Set 8 | bajo baudo
# Processing Record 17 of Set 8 | santa cruz
# Processing Record 18 of Set 8 | monrovia
# Processing Record 19 of Set 8 | abu kamal
# Processing Record 20 of Set 8 | padang
# Processing Record 21 of Set 8 | taoudenni
# Processing Record 22 of Set 8 | margherita di savoia
# Processing Record 23 of Set 8 | nouadhibou
# Processing Record 24 of Set 8 | oxapampa
# Processing Record 25 of Set 8 | evensk
# Processing Record 26 of Set 8 | beira
# Processing Record 27 of Set 8 | plettenberg bay
# Processing Record 28 of Set 8 | lawrence
# Processing Record 29 of Set 8 | mar del plata
# Processing Record 30 of Set 8 | strezhevoy
# Processing Record 31 of Set 8 | marrakesh
# Processing Record 32 of Set 8 | beitbridge
# Processing Record 33 of Set 8 | tyup
# Processing Record 34 of Set 8 | saint-philippe
# Processing Record 35 of Set 8 | olinda
# Processing Record 36 of Set 8 | roma
# Processing Record 37 of Set 8 | tura
# Processing Record 38 of Set 8 | chapais
# Processing Record 39 of Set 8 | louisbourg
# Processing Record 40 of Set 8 | marsa matruh
# Processing Record 41 of Set 8 | hamilton
# Processing Record 42 of Set 8 | fort nelson
# Processing Record 43 of Set 8 | abu samrah
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | daoukro
# Processing Record 46 of Set 8 | motril
# Processing Record 47 of Set 8 | joaima
# Processing Record 48 of Set 8 | am timan
# Processing Record 49 of Set 8 | hofn
# Processing Record 50 of Set 8 | magugu
# Processing Record 1 of Set 9 | barrow
# Processing Record 2 of Set 9 | wellington
# Processing Record 3 of Set 9 | kandi
# Processing Record 4 of Set 9 | ejura
# Processing Record 5 of Set 9 | namwala
# Processing Record 6 of Set 9 | stromness
# Processing Record 7 of Set 9 | hulin
# Processing Record 8 of Set 9 | filingue
# Processing Record 9 of Set 9 | neiafu
# Processing Record 10 of Set 9 | tezu
# Processing Record 11 of Set 9 | havre-saint-pierre
# Processing Record 12 of Set 9 | baglan
# Processing Record 13 of Set 9 | grindavik
# Processing Record 14 of Set 9 | tuatapere
# Processing Record 15 of Set 9 | oruro
# Processing Record 16 of Set 9 | bilma
# Processing Record 17 of Set 9 | lincoln
# Processing Record 18 of Set 9 | fortuna
# Processing Record 19 of Set 9 | yugorsk
# Processing Record 20 of Set 9 | hailey
# Processing Record 21 of Set 9 | severo-kurilsk
# Processing Record 22 of Set 9 | fare
# Processing Record 23 of Set 9 | takoradi
# Processing Record 24 of Set 9 | mbuji-mayi
# Processing Record 25 of Set 9 | hami
# Processing Record 26 of Set 9 | verkhoyansk
# Processing Record 27 of Set 9 | lashio
# Processing Record 28 of Set 9 | kavieng
# Processing Record 29 of Set 9 | canberra
# Processing Record 30 of Set 9 | sovetskiy
# Processing Record 31 of Set 9 | general roca
# Processing Record 32 of Set 9 | kahului
# Processing Record 33 of Set 9 | alta floresta
# Processing Record 34 of Set 9 | namibe
# Processing Record 35 of Set 9 | paracuru
# Processing Record 36 of Set 9 | jiuquan
# Processing Record 37 of Set 9 | portland
# Processing Record 38 of Set 9 | ambilobe
# Processing Record 39 of Set 9 | emerald
# Processing Record 40 of Set 9 | flinders
# Processing Record 41 of Set 9 | mackay
# Processing Record 42 of Set 9 | camopi
# Processing Record 43 of Set 9 | nsanje
# Processing Record 44 of Set 9 | khartoum
# Processing Record 45 of Set 9 | catacamas
# Processing Record 46 of Set 9 | bangaon
# Processing Record 47 of Set 9 | mozelos
# Processing Record 48 of Set 9 | hasaki
# Processing Record 49 of Set 9 | lorengau
# Processing Record 50 of Set 9 | luwuk
# Processing Record 1 of Set 10 | santa isabel
# Processing Record 2 of Set 10 | palabuhanratu
# Processing Record 3 of Set 10 | maymanak
# Processing Record 4 of Set 10 | quelimane
# Processing Record 5 of Set 10 | haibowan
# Processing Record 6 of Set 10 | chicama
# Processing Record 7 of Set 10 | katsuura
# Processing Record 8 of Set 10 | la ronge
# Processing Record 9 of Set 10 | buqayq
# Processing Record 10 of Set 10 | doha
# Processing Record 11 of Set 10 | necaxa
# Processing Record 12 of Set 10 | takefu
# Processing Record 13 of Set 10 | kutum
# Processing Record 14 of Set 10 | ketchikan
# Processing Record 15 of Set 10 | saint anthony
# Processing Record 16 of Set 10 | sao felix do xingu
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | bukavu
# Processing Record 19 of Set 10 | port alfred
# Processing Record 20 of Set 10 | tiksi
# Processing Record 21 of Set 10 | vilyuysk
# Processing Record 22 of Set 10 | sioux lookout
# Processing Record 23 of Set 10 | saint-pierre
# Processing Record 24 of Set 10 | havre
# Processing Record 25 of Set 10 | semey
# Processing Record 26 of Set 10 | buchanan
# Processing Record 27 of Set 10 | nelson bay
# Processing Record 28 of Set 10 | gat
# Processing Record 29 of Set 10 | kyabe
# Processing Record 30 of Set 10 | tiznit
# Processing Record 31 of Set 10 | buzmeyin
# Processing Record 32 of Set 10 | tabou
# Processing Record 33 of Set 10 | yining
# Processing Record 34 of Set 10 | leirvik
# Processing Record 35 of Set 10 | carballo
# Processing Record 36 of Set 10 | mao
# Processing Record 37 of Set 10 | eureka
# Processing Record 38 of Set 10 | shingu
# Processing Record 39 of Set 10 | paamiut
# Processing Record 40 of Set 10 | islamkot
# Processing Record 41 of Set 10 | wewak
# Processing Record 42 of Set 10 | ushtobe
# Processing Record 43 of Set 10 | gravelbourg
# Processing Record 44 of Set 10 | pacific grove
# Processing Record 45 of Set 10 | ascension
# Processing Record 46 of Set 10 | soure
# Processing Record 47 of Set 10 | pilar
# Processing Record 48 of Set 10 | san rafael
# Processing Record 49 of Set 10 | ampere
# Processing Record 50 of Set 10 | camabatela
# Processing Record 1 of Set 11 | birin
# Processing Record 2 of Set 11 | port macquarie
# Processing Record 3 of Set 11 | banda aceh
# Processing Record 4 of Set 11 | pevek
# Processing Record 5 of Set 11 | amderma
# Processing Record 6 of Set 11 | hundorp
# Processing Record 7 of Set 11 | ponta do sol
# Processing Record 8 of Set 11 | tazovskiy
# Processing Record 9 of Set 11 | alofi
# Processing Record 10 of Set 11 | qaanaaq
# Processing Record 11 of Set 11 | ruzomberok
# Processing Record 12 of Set 11 | manzil tamim
# Processing Record 13 of Set 11 | morant bay
# Processing Record 14 of Set 11 | krutinka
# Processing Record 15 of Set 11 | mahibadhoo
# Processing Record 16 of Set 11 | kardla
# Processing Record 17 of Set 11 | san patricio
# Processing Record 18 of Set 11 | daru
# Processing Record 19 of Set 11 | kungurtug
# Processing Record 20 of Set 11 | kathmandu
# Processing Record 21 of Set 11 | lavrentiya
# Processing Record 22 of Set 11 | staroye drozhzhanoye
# Processing Record 23 of Set 11 | teahupoo
# Processing Record 24 of Set 11 | cabedelo
# Processing Record 25 of Set 11 | balakhta
# Processing Record 26 of Set 11 | phan rang
# Processing Record 27 of Set 11 | ahuimanu
# Processing Record 28 of Set 11 | esso
# Processing Record 29 of Set 11 | coihaique
# Processing Record 30 of Set 11 | tromso
# Processing Record 31 of Set 11 | khani
# Processing Record 32 of Set 11 | kodiak
# Processing Record 33 of Set 11 | lagunas
# Processing Record 34 of Set 11 | kindersley
# Processing Record 35 of Set 11 | vanimo
# Processing Record 36 of Set 11 | hailar
# Processing Record 37 of Set 11 | omsukchan
# Processing Record 38 of Set 11 | caraballeda
# Processing Record 39 of Set 11 | seoul
# Processing Record 40 of Set 11 | tautira
# Processing Record 41 of Set 11 | tasiilaq
# Processing Record 42 of Set 11 | guanare
# Processing Record 43 of Set 11 | qaracala
# Processing Record 44 of Set 11 | katobu
# Processing Record 45 of Set 11 | busembatia
# Processing Record 46 of Set 11 | antalaha
# Processing Record 47 of Set 11 | bambous virieux
# Processing Record 48 of Set 11 | maldonado
# Processing Record 49 of Set 11 | leh
# Processing Record 50 of Set 11 | verkhnyaya inta
# Processing Record 1 of Set 12 | imbituva
# Processing Record 2 of Set 12 | san cristobal
# Processing Record 3 of Set 12 | vorukh
# Processing Record 4 of Set 12 | kayes
# Processing Record 5 of Set 12 | amparai
# Processing Record 6 of Set 12 | khasan
# Processing Record 7 of Set 12 | severnoye
# Processing Record 8 of Set 12 | bethel
# Processing Record 9 of Set 12 | arkansas city
# Processing Record 10 of Set 12 | berlevag
# Processing Record 11 of Set 12 | vila franca do campo
# Processing Record 12 of Set 12 | butembo
# Processing Record 13 of Set 12 | huautla
# Processing Record 14 of Set 12 | half moon bay
# Processing Record 15 of Set 12 | chumikan
# Processing Record 16 of Set 12 | linares
# Processing Record 17 of Set 12 | kiunga
# Processing Record 18 of Set 12 | senanga
# Processing Record 19 of Set 12 | qaqortoq
# Processing Record 20 of Set 12 | rio grande
# Processing Record 21 of Set 12 | jambi
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | igdir
# Processing Record 24 of Set 12 | yanam
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | chantilly
# Processing Record 27 of Set 12 | upernavik
# Processing Record 28 of Set 12 | itaqui
# Processing Record 29 of Set 12 | pasni
# Processing Record 30 of Set 12 | buta
# Processing Record 31 of Set 12 | nador
# Processing Record 32 of Set 12 | lethem
# Processing Record 33 of Set 12 | tokur
# Processing Record 34 of Set 12 | biak
# Processing Record 35 of Set 12 | marsh harbour
# Processing Record 36 of Set 12 | kisangani
# Processing Record 37 of Set 12 | comodoro rivadavia
# Processing Record 38 of Set 12 | whitehorse
# Processing Record 39 of Set 12 | roebourne
# Processing Record 40 of Set 12 | jalu
# Processing Record 41 of Set 12 | gasa
# Processing Record 42 of Set 12 | nuuk
# Processing Record 43 of Set 12 | chikoy
# Processing Record 44 of Set 12 | mahadday weyne
# Processing Record 45 of Set 12 | luena
# Processing Record 46 of Set 12 | damaturu
# Processing Record 47 of Set 12 | vicente guerrero
# Processing Record 48 of Set 12 | baykit
# Processing Record 49 of Set 12 | paoua
# Processing Record 50 of Set 12 | kanigoro
# Processing Record 1 of Set 13 | copiapo
# Processing Record 2 of Set 13 | egvekinot
# Processing Record 3 of Set 13 | shubarkuduk
# Processing Record 4 of Set 13 | mabaruma
# Processing Record 5 of Set 13 | chamonix-mont-blanc
# Processing Record 6 of Set 13 | svetlyy
# Processing Record 7 of Set 13 | stornoway
# Processing Record 8 of Set 13 | qui nhon
# Processing Record 9 of Set 13 | kodinsk
# Processing Record 10 of Set 13 | santa eulalia del rio
# Processing Record 11 of Set 13 | wakefield
# Processing Record 12 of Set 13 | bathurst
# Processing Record 13 of Set 13 | naftah
# Processing Record 14 of Set 13 | meulaboh
# Processing Record 15 of Set 13 | lompoc
# Processing Record 16 of Set 13 | saint-georges
# Processing Record 17 of Set 13 | nanortalik
# Processing Record 18 of Set 13 | issoire
# Processing Record 19 of Set 13 | vuktyl
# Processing Record 20 of Set 13 | lolua
# Processing Record 21 of Set 13 | nagato
# Processing Record 22 of Set 13 | maceio
# Processing Record 23 of Set 13 | la crosse
# Processing Record 24 of Set 13 | dubrovnik
# Processing Record 25 of Set 13 | port-gentil
# Processing Record 26 of Set 13 | mumbwa
# Processing Record 27 of Set 13 | ruatoria
# Processing Record 28 of Set 13 | sorrento
# Processing Record 29 of Set 13 | kontagora
# Processing Record 30 of Set 13 | atar
# Processing Record 31 of Set 13 | narsaq
# Processing Record 32 of Set 13 | sur
# Processing Record 33 of Set 13 | sehithwa
# Processing Record 34 of Set 13 | noumea
# Processing Record 35 of Set 13 | ko samui
# Processing Record 36 of Set 13 | taybad
# Processing Record 37 of Set 13 | sudislavl
# Processing Record 38 of Set 13 | ilulissat
# Processing Record 39 of Set 13 | sault sainte marie
# Processing Record 40 of Set 13 | patti
# Processing Record 41 of Set 13 | jadu
# Processing Record 42 of Set 13 | san matias
# Processing Record 43 of Set 13 | eydhafushi
# Processing Record 44 of Set 13 | joao pinheiro
# Processing Record 45 of Set 13 | gondar
# Processing Record 46 of Set 13 | cururupu
# Processing Record 47 of Set 13 | moen
# Processing Record 48 of Set 13 | thompson
# Processing Record 49 of Set 13 | dudinka
# Processing Record 50 of Set 13 | namatanai
# Processing Record 1 of Set 14 | port hardy
# Processing Record 2 of Set 14 | naze
# Processing Record 3 of Set 14 | skagastrond
# Processing Record 4 of Set 14 | mbandaka
# Processing Record 5 of Set 14 | maningrida
# Processing Record 6 of Set 14 | cherskiy
# Processing Record 7 of Set 14 | bedele
# Processing Record 8 of Set 14 | victor harbor
# Processing Record 9 of Set 14 | corrente
# Processing Record 10 of Set 14 | isangel
# Processing Record 11 of Set 14 | taltal
# Processing Record 12 of Set 14 | bayevo
# Processing Record 13 of Set 14 | palana
# Processing Record 14 of Set 14 | le passage
# Processing Record 15 of Set 14 | khakhea
# Processing Record 16 of Set 14 | asosa
# Processing Record 17 of Set 14 | condado
# Processing Record 18 of Set 14 | jacareacanga
# Processing Record 19 of Set 14 | lakes entrance
# Processing Record 20 of Set 14 | itarema
# Processing Record 21 of Set 14 | labuhan
# Processing Record 22 of Set 14 | kuvandyk
# Processing Record 23 of Set 14 | mumford
# Processing Record 24 of Set 14 | aswan
# Processing Record 25 of Set 14 | radford
# Processing Record 26 of Set 14 | locri
# Processing Record 27 of Set 14 | dezhou
# Processing Record 28 of Set 14 | fulacunda
# Processing Record 29 of Set 14 | talnakh
# Processing Record 30 of Set 14 | kitui
# Processing Record 31 of Set 14 | brae
# Processing Record 32 of Set 14 | suraabad
# Processing Record 33 of Set 14 | montrose
# Processing Record 34 of Set 14 | ayan
# Processing Record 35 of Set 14 | lima
# Processing Record 36 of Set 14 | kaeo
# Processing Record 37 of Set 14 | cottbus
# Processing Record 38 of Set 14 | san felipe
# Processing Record 39 of Set 14 | geraldton
# Processing Record 40 of Set 14 | la palma
# Processing Record 41 of Set 14 | slave lake
# Processing Record 42 of Set 14 | poum
# Processing Record 43 of Set 14 | sinop
# Processing Record 44 of Set 14 | sangar
# Processing Record 45 of Set 14 | dingle
# Processing Record 46 of Set 14 | manokwari
# Processing Record 47 of Set 14 | atasu
# Processing Record 48 of Set 14 | oktyabrskiy
# Processing Record 49 of Set 14 | ugoofaaru
# Processing Record 50 of Set 14 | dunedin
# Processing Record 1 of Set 15 | shunyi
# Processing Record 2 of Set 15 | bacuit
# Processing Record 3 of Set 15 | henties bay
# Processing Record 4 of Set 15 | shimoda
# Processing Record 5 of Set 15 | douglas
# Processing Record 6 of Set 15 | santa maria
# Processing Record 7 of Set 15 | grand centre
# Processing Record 8 of Set 15 | brownsville
# Processing Record 9 of Set 15 | huangpu
# Processing Record 10 of Set 15 | timiryazevskoye
# Processing Record 11 of Set 15 | matay
# Processing Record 12 of Set 15 | nichinan
# Processing Record 13 of Set 15 | lamar
# Processing Record 14 of Set 15 | quatre cocos
# Processing Record 15 of Set 15 | nortelandia
# Processing Record 16 of Set 15 | ballina
# Processing Record 17 of Set 15 | carutapera
# Processing Record 18 of Set 15 | antofagasta
# Processing Record 19 of Set 15 | ostrovnoy
# Processing Record 20 of Set 15 | letka
# Processing Record 21 of Set 15 | braganca
# Processing Record 22 of Set 15 | grodzisk mazowiecki
# Processing Record 23 of Set 15 | yumen
# Processing Record 24 of Set 15 | harper
# Processing Record 25 of Set 15 | stara zagora
# Processing Record 26 of Set 15 | svetlogorsk
# Processing Record 27 of Set 15 | krasnoselkup
# Processing Record 28 of Set 15 | udon thani
# Processing Record 29 of Set 15 | port said
# Processing Record 30 of Set 15 | acarau
# Processing Record 31 of Set 15 | vitim
# Processing Record 32 of Set 15 | deyang
# Processing Record 33 of Set 15 | gbongan
# Processing Record 34 of Set 15 | sola
# Processing Record 35 of Set 15 | adrar
# Processing Record 36 of Set 15 | yonago
# Processing Record 37 of Set 15 | quetzaltepec
# Processing Record 38 of Set 15 | kirakira
# Processing Record 39 of Set 15 | praia da vitoria
# Processing Record 40 of Set 15 | zhanaozen
# Processing Record 41 of Set 15 | mashhad
# Processing Record 42 of Set 15 | ancud
# Processing Record 43 of Set 15 | huarmey
# Processing Record 44 of Set 15 | moyale
# Processing Record 45 of Set 15 | cap malheureux
# Processing Record 46 of Set 15 | inhambane
# Processing Record 47 of Set 15 | necochea
# Processing Record 48 of Set 15 | goksun
# Processing Record 49 of Set 15 | ust-kuyga
# Processing Record 50 of Set 15 | dekoa
# Processing Record 1 of Set 16 | san jose
# Processing Record 2 of Set 16 | zhezkazgan
# Processing Record 3 of Set 16 | sarkand
# Processing Record 4 of Set 16 | kulhudhuffushi
# Processing Record 5 of Set 16 | khorramshahr
# Processing Record 6 of Set 16 | zhigansk
# Processing Record 7 of Set 16 | fukue
# Processing Record 8 of Set 16 | pimenteiras
# Processing Record 9 of Set 16 | victoria
# Processing Record 10 of Set 16 | wajima
# Processing Record 11 of Set 16 | galesong
# Processing Record 12 of Set 16 | havoysund
# Processing Record 13 of Set 16 | miyazu
# Processing Record 14 of Set 16 | ukiah
# Processing Record 15 of Set 16 | klamath falls
# Processing Record 16 of Set 16 | safwah
# Processing Record 17 of Set 16 | tahta
# Processing Record 18 of Set 16 | yeppoon
# Processing Record 19 of Set 16 | cayenne
# Processing Record 20 of Set 16 | ripoll
# Processing Record 21 of Set 16 | pisco
# Processing Record 22 of Set 16 | prince rupert
# Processing Record 23 of Set 16 | gorontalo
# Processing Record 24 of Set 16 | ginda
# Processing Record 25 of Set 16 | mount isa
# Processing Record 26 of Set 16 | athabasca
# Processing Record 27 of Set 16 | lososina
# Processing Record 28 of Set 16 | amet
# Processing Record 29 of Set 16 | bereda
# Processing Record 30 of Set 16 | yeniseysk
# Processing Record 31 of Set 16 | pangai
# Processing Record 32 of Set 16 | palmer
# Processing Record 33 of Set 16 | thinadhoo
# Processing Record 34 of Set 16 | jumla
# Processing Record 35 of Set 16 | redding
# Processing Record 36 of Set 16 | tevaitoa
# Processing Record 37 of Set 16 | bay-khaak
# Processing Record 38 of Set 16 | karamken
# Processing Record 39 of Set 16 | beloha
# Processing Record 40 of Set 16 | tornio
# Processing Record 41 of Set 16 | santa marta de tormes
# Processing Record 42 of Set 16 | sao joao dos patos
# Processing Record 43 of Set 16 | kumluca
# Processing Record 44 of Set 16 | miandrivazo
# Processing Record 45 of Set 16 | umuahia
# Processing Record 46 of Set 16 | kostomuksha
# Processing Record 47 of Set 16 | luang prabang
# Processing Record 48 of Set 16 | puerto escondido
# Processing Record 49 of Set 16 | zacualpan
# Processing Record 50 of Set 16 | karaul
# Processing Record 1 of Set 17 | tilichiki
# Processing Record 2 of Set 17 | ciechocinek
# Processing Record 3 of Set 17 | bosaso
# Processing Record 4 of Set 17 | ixtapa
# Processing Record 5 of Set 17 | ivanteyevka
# Processing Record 6 of Set 17 | port augusta
# Processing Record 7 of Set 17 | krasnokholm
# Processing Record 8 of Set 17 | chivay
# Processing Record 9 of Set 17 | caravelas
# Processing Record 10 of Set 17 | beringovskiy
# Processing Record 11 of Set 17 | wulanhaote
# Processing Record 12 of Set 17 | santa fe
# Processing Record 13 of Set 17 | la sarre
# Processing Record 14 of Set 17 | muravlenko
# Processing Record 15 of Set 17 | hayden
# Processing Record 16 of Set 17 | puerto gaitan
# Processing Record 17 of Set 17 | sterling
# Processing Record 18 of Set 17 | guajara-mirim
# Processing Record 19 of Set 17 | port lincoln
# Processing Record 20 of Set 17 | bontang
# Processing Record 21 of Set 17 | koygorodok
# Processing Record 22 of Set 17 | kez
# Processing Record 23 of Set 17 | vostok
# Processing Record 24 of Set 17 | dzhusaly
# Processing Record 25 of Set 17 | igarka
# Processing Record 26 of Set 17 | lengshuitan
# Processing Record 27 of Set 17 | kamuli
# Processing Record 28 of Set 17 | maragogi
# Processing Record 29 of Set 17 | shieli
# Processing Record 30 of Set 17 | ostuacan
# Processing Record 31 of Set 17 | tacuarembo
# Processing Record 32 of Set 17 | dinar
# Processing Record 33 of Set 17 | matehuala
# Processing Record 34 of Set 17 | young
# Processing Record 35 of Set 17 | panjakent
# Processing Record 36 of Set 17 | zabol
# Processing Record 37 of Set 17 | college
# Processing Record 38 of Set 17 | bubaque
# Processing Record 39 of Set 17 | corpus christi
# Processing Record 40 of Set 17 | mokshan
# Processing Record 41 of Set 17 | thivai
# Processing Record 42 of Set 17 | north bend
# Processing Record 43 of Set 17 | mocorito
# Processing Record 44 of Set 17 | ovsyanka
# Processing Record 45 of Set 17 | valparaiso
# Processing Record 46 of Set 17 | kidal
# Processing Record 47 of Set 17 | malgrat de mar
# Processing Record 48 of Set 17 | georgiyevka
# Processing Record 49 of Set 17 | kjollefjord
# Processing Record 50 of Set 17 | san joaquin
# Processing Record 1 of Set 18 | gaoua
# Processing Record 2 of Set 18 | paysandu
# Processing Record 3 of Set 18 | kudahuvadhoo
# Processing Record 4 of Set 18 | kavaratti
# Processing Record 5 of Set 18 | daman
# Processing Record 6 of Set 18 | palora
# Processing Record 7 of Set 18 | bandarbeyla
# Processing Record 8 of Set 18 | safaga
# Processing Record 9 of Set 18 | upington
# Processing Record 10 of Set 18 | toftir
# Processing Record 11 of Set 18 | furano
# Processing Record 12 of Set 18 | manuk mangkaw
# Processing Record 13 of Set 18 | aklavik
# Processing Record 14 of Set 18 | waw
# Processing Record 15 of Set 18 | topeka
# Processing Record 16 of Set 18 | warqla
# Processing Record 17 of Set 18 | zhuhai
# Processing Record 18 of Set 18 | ilovlya
# Processing Record 19 of Set 18 | panzhihua
# Processing Record 20 of Set 18 | iki-burul
# Processing Record 21 of Set 18 | sarany
# Processing Record 22 of Set 18 | glasgow
# Processing Record 23 of Set 18 | boshnyakovo
# Processing Record 24 of Set 18 | srednekolymsk
# Processing Record 25 of Set 18 | esik
# Processing Record 26 of Set 18 | honiara
# Processing Record 27 of Set 18 | seymchan
# Processing Record 28 of Set 18 | bahia de caraquez
# Processing Record 29 of Set 18 | cantaura
# Processing Record 30 of Set 18 | kloulklubed
# Processing Record 31 of Set 18 | smithers
# Processing Record 32 of Set 18 | zhaozhou
# Processing Record 33 of Set 18 | nabire
# Processing Record 34 of Set 18 | parfenyevo
# Processing Record 35 of Set 18 | sinkat
# Processing Record 36 of Set 18 | azacualpa
# Processing Record 37 of Set 18 | chulman
# Processing Record 38 of Set 18 | kununurra
# Processing Record 39 of Set 18 | swellendam
# Processing Record 40 of Set 18 | dryden
# Processing Record 41 of Set 18 | mogadishu
# Processing Record 42 of Set 18 | calvinia
# Processing Record 43 of Set 18 | qandala
# Processing Record 44 of Set 18 | madanapalle
# Processing Record 45 of Set 18 | ngunguru
# Processing Record 46 of Set 18 | wahpeton
# Processing Record 47 of Set 18 | aksum
# Processing Record 48 of Set 18 | tongchuan
# Processing Record 49 of Set 18 | mineiros
# Processing Record 50 of Set 18 | pedernales
# Processing Record 1 of Set 19 | mtambile
# Processing Record 2 of Set 19 | kautokeino
# Processing Record 3 of Set 19 | iberia
# Processing Record 4 of Set 19 | liverpool
# Processing Record 5 of Set 19 | picayune
# Processing Record 6 of Set 19 | constitucion
# Processing Record 7 of Set 19 | kosh-agach
# Processing Record 8 of Set 19 | aksu
# Processing Record 9 of Set 19 | escanaba
# Processing Record 10 of Set 19 | baghdad
# Processing Record 11 of Set 19 | ust-bolsheretsk
# Processing Record 12 of Set 19 | yerbogachen
# Processing Record 13 of Set 19 | bodden town
# Processing Record 14 of Set 19 | sept-iles
# Processing Record 15 of Set 19 | meadow lake
# Processing Record 16 of Set 19 | strzelce krajenskie
# Processing Record 17 of Set 19 | tucurui
# Processing Record 18 of Set 19 | kondinskoye
# Processing Record 19 of Set 19 | sabang
# Processing Record 20 of Set 19 | coos bay
# Processing Record 21 of Set 19 | nisia floresta
# Processing Record 22 of Set 19 | tiruchchendur
# Processing Record 23 of Set 19 | carndonagh
# Processing Record 24 of Set 19 | te anau
# Processing Record 25 of Set 19 | cervo
# Processing Record 26 of Set 19 | little current
# Processing Record 27 of Set 19 | kupang
# Processing Record 28 of Set 19 | darlawn
# Processing Record 29 of Set 19 | ilabaya
# Processing Record 30 of Set 19 | grand gaube
# Processing Record 31 of Set 19 | moose factory
# Processing Record 32 of Set 19 | eskasem
# Processing Record 33 of Set 19 | helena
# Processing Record 34 of Set 19 | kazalinsk
# Processing Record 35 of Set 19 | kalmunai
# Processing Record 36 of Set 19 | ratnagiri
# Processing Record 37 of Set 19 | kirkuk
# Processing Record 38 of Set 19 | esperanza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa -35.2813  149.1292    292.62        67          90
# 1            Asau -35.2813  149.1292    292.62        66         100
# 2         Husavik -35.2813  149.1292    292.29        67         100
# 3       Busselton -35.2813  149.1292    292.29        67         100
# 4    Longyearbyen -35.2813  149.1292    292.29        67         100
# 5         Ushuaia -35.2813  149.1292    292.29        67         100
# 6        Tessalit -35.2813  149.1292    292.62        66         100
# 7        Cidreira -35.2813  149.1292    292.29        67         100
# 8           Mecca -35.2813  149.1292    292.62        67          90
# 9  Hanmer Springs -35.2813  149.1292    292.29        67         100
#
#    Wind Speed Country                 Date
# 0        4.12      AU  2022-02-07 00:00:27
# 1        4.12      AU  2022-02-07 00:03:33
# 2        4.12      AU  2022-02-07 00:00:11
# 3        4.12      AU  2022-02-07 00:00:15
# 4        4.12      AU  2022-02-07 00:00:15
# 5        4.12      AU  2022-02-07 00:00:11
# 6        4.12      AU  2022-02-07 00:03:33
# 7        4.12      AU  2022-02-07 00:00:15
# 8        4.12      AU  2022-02-07 00:00:27
# 9        4.12      AU  2022-02-07 00:00:11

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df= city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file= "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
